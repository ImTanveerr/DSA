// %% [markdown]
// ### sum of 1 to 100

// %%
let sum=0;
for (let i=1; i<=100; i++){
    sum+=i;
}
// Out:
// 5050

// %% [markdown]
// ### Multiplication table of 5

// %%
for (let i=1;i<=10;i++){
    console.log(`5* ${i} = ${5*i}`);
}
